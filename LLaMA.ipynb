# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharmoon/Generative_AI/blob/main/LLaMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LlaMA

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 49.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.5/177.5 kB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.5 MB/s eta 0:00:00

# %%
# !pip -qqq install bitsandbytes accelerate

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
#pip install langchain

# %%
#pip install accelerate

# %%
from langchain import HuggingFacePipeline
from transformers import AutoTokenizer
import transformers
import torch

model = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    eos_token_id=tokenizer.eos_token_id
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
llm = HuggingFacePipeline(pipeline = pipeline, model_kwargs = {'temperature':0})

# %%
our_query = "What is the currency of country Japan?"
completion = llm(our_query)
print(completion)
# Out:
# Answer: The currency of Japan is the Japanese yen (JPY).

# %%
our_query = "What are the 3 causes of glacier meltdowns?"
completion = llm(our_query)
print(completion)
# Out:
# Glaciers are large, slow-moving rivers of ice that are formed in high mountains or at the poles. They play a crucial role in shaping the Earth's landscape and regulating the global climate. However, glaciers are melting at an unprecedented rate due to a combination of natural and human-induced factors. Here are the three main causes of glacier meltdowns:
#
# 1. Climate Change: Global warming is the primary cause of glacier meltdowns. As the Earth's atmosphere traps more heat due to the increasing concentration of greenhouse gases, the temperature of the planet rises, causing the ice at the glaciers to melt. The melting process is accelerated by the fact that glaciers are sensitive to temperature changes, with a small increase in temperature leading to a larger increase in meltwater.
# ...

# %%
our_query = "What are the benefits of eating soaked almond?"
completion = llm(our_query)
print(completion)
# Out:
# Answer: Soaking almonds in water can provide several benefits, including:
#
# 1. Better digestion: Soaking almonds in water can break down some of the phytic acid and enzyme inhibitors, making the nutrients more easily accessible to your body.
# 2. Increased bioavailability: Soaking almonds can increase the bioavailability of nutrients like vitamin E, calcium, and magnesium.
# 3. Reduced antinutrients: Soaking almonds can reduce the levels of antinutrients like phytic acid, which can interfere with nutrient absorption.
# 4. Improved texture: Soaking almonds can make them softer and easier to chew.
# 5. Increased nutrient absorption: Soaking almonds can increase the absorption of nutrients like vitamin E, calcium, and magnesium.
# 6. Lower risk of allergies: Soaking almonds can reduce the risk of allergies by breaking down some of the proteins that can cause an allergic reaction.
# ...

# %%
# from langchain import PromptTemplate,  LLMChain

# template = """
#               You are an intelligent chatbot that gives out useful information to humans.
#               You return the responses in sentences with arrows at the start of each sentence
#               {query}
#            """

# prompt = PromptTemplate(template=template, input_variables=["query"])

# llm_chain = LLMChain(prompt=prompt, llm=llm)

# %%
# print(llm_chain.run('What are the 3 causes of glacier meltdowns?'))

# %%
# print(llm_chain.run('What are the benefits of eating soaked almond?'))

# %%
# import pandas as pd
# from langchain.agents import create_csv_agent
# df=pd.read_csv('/content/sample_data/california_housing_test.csv')
# df.head(4)

# %%
# def load_answer(question):
#     model = create_csv_agent(llm,df,verbose=True)
#     question = question + " using tool python_repl_ast"
#     answer=model(question)
#     return answer

# user_input2= "what is the average total_rooms,"
# response2 = load_answer(user_input2)
# print(response2)
# print("****************************************")

# %% [markdown]
# =====================================
